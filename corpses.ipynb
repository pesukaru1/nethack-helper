# %%
import os
from bs4 import BeautifulSoup
import re

HTMLFILE = 'corpses.html'

if os.path.exists(HTMLFILE):
    print('File exists')

with open(HTMLFILE, 'r', encoding='utf-8') as file:
    html = file.read()  # читает весь файл как строку
    soup = BeautifulSoup(html, "lxml")
# Out:
# File exists

# %%
# %pwd
# Out:
# '/Volumes/data/prjcts/nethack-helper'

# %%
# !ls
# Out:
# anaconda_projects         inverted_index_search2.py price_id.html
# corpses.csv               monsters.h                price_id.mhtml
# corpses.html              monsters.html             price_id.py
# corpses.ipynb             monsters360.csv           price_id_draft.py
# interface.py              nh-lgsq                   sessions
# inverted_index_search.py  pandas-test.py            tz
